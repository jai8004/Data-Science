# %% [markdown]
# <a href="https://colab.research.google.com/github/jai8004/Data-Science/blob/main/DeepLearning/NLP/Transformers/NLP_Transformer_Colab_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61979ca4-929c-44d2-8a65-33362f5de912" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61979ca4-929c-44d2-8a65-33362f5de912">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving requirements.txt to requirements.txt

# %%
import os ,sys
from google.colab import drive

drive.mount('/content/drive')
nb_path = '/content/NLPTNB'
os.symlink('/content/drive/My Drive/Colab Notebooks',nb_path)
sys.path.insert(0,nb_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --target=$nb_path -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 321 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 114 kB 63.0 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 59.7 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 29.6 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 19.9 MB/s
# ...
#      |████████████████████████████████| 285 kB 66.1 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 25.6 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 12.8 MB 23.5 MB/s
# ...
#      |████████████████████████████████| 277 kB 53.9 MB/s
# ...
#      |████████████████████████████████| 454.4 MB 9.4 kB/s
# ...
#      |████████████████████████████████| 120 kB 51.6 MB/s
# ...
#      |████████████████████████████████| 138 kB 48.2 MB/s
# ...
#      |████████████████████████████████| 149 kB 45.0 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 54.2 MB/s
# ...

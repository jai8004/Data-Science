# %% [markdown]
# <a href="https://colab.research.google.com/github/jai8004/Data-Science/blob/main/DeepLearning/Basics/02.Basics_Pytorch_Model_Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression using Pytorch

# %%
#%% packages
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import seaborn as sns

# %%
#%% data import
cars_file = 'https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv'
cars = pd.read_csv(cars_file)
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
#%% visualize the model
#replicating regessrion line with the model
sns.scatterplot(x='wt',y='mpg',data=cars)
sns.regplot(x='wt',y='mpg',data=cars)
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %% [markdown]
# ### Basic Regression Model Implementation

# %%
# convert data to tensors
X_list = cars.wt.values
X_np = np.array(X_list,dtype=np.float32).reshape(-1,1)
y_list = cars.mpg.values.tolist()
y_np = np.array(y_list,dtype=np.float32).reshape(-1,1)
X = torch.from_numpy(X_np)
y = torch.tensor(y_list)

# %%
# setting up weights and biases
w = torch.rand(1,requires_grad=True, dtype = torch.float64)
b = torch.rand(1,requires_grad=True, dtype=torch.float64)

# %%
#setting up epochs and learning rate
num_epochs = 200
learning_rate = 2e-3

# %%
#training model
for epioch in range(num_epochs):
  for i in range(len(X)):
    #forward pass
    y_preidct = X[i]*w+b
    #calculate the loss
    loss_tensor = torch.pow(y_preidct - y[i],2)
    #backward pass
    loss_tensor.backward()
    #extract loss
    loss_value = loss_tensor.data[0]
    #update weights and biases
    with torch.no_grad():
      w-=w.grad*learning_rate
      b -= b.grad*learning_rate
      w.grad.zero_()
      b.grad.zero_()
  print(loss_value)
# Out:
# tensor(81.0647, dtype=torch.float64)
# tensor(41.9548, dtype=torch.float64)
# tensor(35.0787, dtype=torch.float64)
# tensor(33.1883, dtype=torch.float64)
# tensor(32.2369, dtype=torch.float64)
# tensor(31.4801, dtype=torch.float64)
# tensor(30.7733, dtype=torch.float64)
# tensor(30.0879, dtype=torch.float64)
# tensor(29.4182, dtype=torch.float64)
# tensor(28.7627, dtype=torch.float64)
# tensor(28.1209, dtype=torch.float64)
# tensor(27.4924, dtype=torch.float64)
# tensor(26.8772, dtype=torch.float64)
# tensor(26.2747, dtype=torch.float64)
# tensor(25.6849, dtype=torch.float64)
# tensor(25.1074, dtype=torch.float64)
# tensor(24.5420, dtype=torch.float64)
# tensor(23.9885, dtype=torch.float64)
# tensor(23.4466, dtype=torch.float64)
# tensor(22.9160, dtype=torch.float64)
# tensor(22.3966, dtype=torch.float64)
# tensor(21.8882, dtype=torch.float64)
# tensor(21.3904, dtype=torch.float64)
# tensor(20.9032, dtype=torch.float64)
# tensor(20.4262, dtype=torch.float64)
# tensor(19.9593, dtype=torch.float64)
# tensor(19.5023, dtype=torch.float64)
# tensor(19.0549, dtype=torch.float64)
# tensor(18.6170, dtype=torch.float64)
# tensor(18.1884, dtype=torch.float64)
# tensor(17.7689, dtype=torch.float64)
# tensor(17.3583, dtype=torch.float64)
# tensor(16.9564, dtype=torch.float64)
# tensor(16.5631, dtype=torch.float64)
# tensor(16.1782, dtype=torch.float64)
# tensor(15.8015, dtype=torch.float64)
# tensor(15.4328, dtype=torch.float64)
# tensor(15.0720, dtype=torch.float64)
# tensor(14.7189, dtype=torch.float64)
# tensor(14.3734, dtype=torch.float64)
# tensor(14.0353, dtype=torch.float64)
# tensor(13.7045, dtype=torch.float64)
# tensor(13.3807, dtype=torch.float64)
# tensor(13.0640, dtype=torch.float64)
# tensor(12.7540, dtype=torch.float64)
# tensor(12.4508, dtype=torch.float64)
# tensor(12.1541, dtype=torch.float64)
# tensor(11.8638, dtype=torch.float64)
# tensor(11.5798, dtype=torch.float64)
# tensor(11.3020, dtype=torch.float64)
# tensor(11.0302, dtype=torch.float64)
# tensor(10.7643, dtype=torch.float64)
# tensor(10.5042, dtype=torch.float64)
# tensor(10.2497, dtype=torch.float64)
# tensor(10.0008, dtype=torch.float64)
# tensor(9.7574, dtype=torch.float64)
# tensor(9.5193, dtype=torch.float64)
# tensor(9.2864, dtype=torch.float64)
# tensor(9.0586, dtype=torch.float64)
# tensor(8.8358, dtype=torch.float64)
# tensor(8.6179, dtype=torch.float64)
# tensor(8.4049, dtype=torch.float64)
# tensor(8.1965, dtype=torch.float64)
# tensor(7.9927, dtype=torch.float64)
# tensor(7.7935, dtype=torch.float64)
# tensor(7.5987, dtype=torch.float64)
# tensor(7.4082, dtype=torch.float64)
# tensor(7.2219, dtype=torch.float64)
# tensor(7.0398, dtype=torch.float64)
# tensor(6.8618, dtype=torch.float64)
# tensor(6.6877, dtype=torch.float64)
# tensor(6.5176, dtype=torch.float64)
# tensor(6.3512, dtype=torch.float64)
# tensor(6.1886, dtype=torch.float64)
# tensor(6.0297, dtype=torch.float64)
# tensor(5.8743, dtype=torch.float64)
# tensor(5.7225, dtype=torch.float64)
# tensor(5.5741, dtype=torch.float64)
# tensor(5.4290, dtype=torch.float64)
# tensor(5.2873, dtype=torch.float64)
# tensor(5.1488, dtype=torch.float64)
# tensor(5.0135, dtype=torch.float64)
# tensor(4.8812, dtype=torch.float64)
# tensor(4.7520, dtype=torch.float64)
# tensor(4.6257, dtype=torch.float64)
# tensor(4.5024, dtype=torch.float64)
# tensor(4.3819, dtype=torch.float64)
# tensor(4.2642, dtype=torch.float64)
# tensor(4.1492, dtype=torch.float64)
# tensor(4.0368, dtype=torch.float64)
# tensor(3.9271, dtype=torch.float64)
# tensor(3.8200, dtype=torch.float64)
# tensor(3.7153, dtype=torch.float64)
# tensor(3.6132, dtype=torch.float64)
# tensor(3.5134, dtype=torch.float64)
# tensor(3.4159, dtype=torch.float64)
# tensor(3.3208, dtype=torch.float64)
# tensor(3.2279, dtype=torch.float64)
# tensor(3.1372, dtype=torch.float64)
# tensor(3.0487, dtype=torch.float64)
# tensor(2.9622, dtype=torch.float64)
# tensor(2.8779, dtype=torch.float64)
# tensor(2.7956, dtype=torch.float64)
# tensor(2.7152, dtype=torch.float64)
# tensor(2.6368, dtype=torch.float64)
# tensor(2.5603, dtype=torch.float64)
# tensor(2.4856, dtype=torch.float64)
# tensor(2.4128, dtype=torch.float64)
# tensor(2.3417, dtype=torch.float64)
# tensor(2.2724, dtype=torch.float64)
# tensor(2.2047, dtype=torch.float64)
# tensor(2.1388, dtype=torch.float64)
# tensor(2.0744, dtype=torch.float64)
# tensor(2.0117, dtype=torch.float64)
# tensor(1.9505, dtype=torch.float64)
# tensor(1.8909, dtype=torch.float64)
# tensor(1.8327, dtype=torch.float64)
# tensor(1.7760, dtype=torch.float64)
# tensor(1.7208, dtype=torch.float64)
# tensor(1.6669, dtype=torch.float64)
# tensor(1.6144, dtype=torch.float64)
# tensor(1.5633, dtype=torch.float64)
# tensor(1.5134, dtype=torch.float64)
# tensor(1.4649, dtype=torch.float64)
# tensor(1.4175, dtype=torch.float64)
# tensor(1.3715, dtype=torch.float64)
# tensor(1.3266, dtype=torch.float64)
# tensor(1.2829, dtype=torch.float64)
# tensor(1.2403, dtype=torch.float64)
# tensor(1.1989, dtype=torch.float64)
# tensor(1.1585, dtype=torch.float64)
# tensor(1.1192, dtype=torch.float64)
# tensor(1.0810, dtype=torch.float64)
# tensor(1.0438, dtype=torch.float64)
# tensor(1.0076, dtype=torch.float64)
# tensor(0.9724, dtype=torch.float64)
# tensor(0.9382, dtype=torch.float64)
# tensor(0.9049, dtype=torch.float64)
# tensor(0.8725, dtype=torch.float64)
# tensor(0.8410, dtype=torch.float64)
# tensor(0.8104, dtype=torch.float64)
# tensor(0.7806, dtype=torch.float64)
# tensor(0.7517, dtype=torch.float64)
# tensor(0.7236, dtype=torch.float64)
# tensor(0.6963, dtype=torch.float64)
# tensor(0.6698, dtype=torch.float64)
# tensor(0.6440, dtype=torch.float64)
# tensor(0.6190, dtype=torch.float64)
# tensor(0.5948, dtype=torch.float64)
# tensor(0.5712, dtype=torch.float64)
# tensor(0.5484, dtype=torch.float64)
# tensor(0.5262, dtype=torch.float64)
# tensor(0.5047, dtype=torch.float64)
# tensor(0.4838, dtype=torch.float64)
# tensor(0.4636, dtype=torch.float64)
# tensor(0.4440, dtype=torch.float64)
# tensor(0.4250, dtype=torch.float64)
# tensor(0.4066, dtype=torch.float64)
# tensor(0.3888, dtype=torch.float64)
# tensor(0.3716, dtype=torch.float64)
# tensor(0.3549, dtype=torch.float64)
# tensor(0.3387, dtype=torch.float64)
# tensor(0.3231, dtype=torch.float64)
# tensor(0.3080, dtype=torch.float64)
# tensor(0.2934, dtype=torch.float64)
# tensor(0.2793, dtype=torch.float64)
# tensor(0.2656, dtype=torch.float64)
# tensor(0.2525, dtype=torch.float64)
# tensor(0.2398, dtype=torch.float64)
# tensor(0.2275, dtype=torch.float64)
# tensor(0.2157, dtype=torch.float64)
# tensor(0.2043, dtype=torch.float64)
# tensor(0.1933, dtype=torch.float64)
# tensor(0.1827, dtype=torch.float64)
# tensor(0.1725, dtype=torch.float64)
# tensor(0.1628, dtype=torch.float64)
# tensor(0.1533, dtype=torch.float64)
# tensor(0.1443, dtype=torch.float64)
# tensor(0.1356, dtype=torch.float64)
# tensor(0.1273, dtype=torch.float64)
# tensor(0.1193, dtype=torch.float64)
# tensor(0.1116, dtype=torch.float64)
# tensor(0.1043, dtype=torch.float64)
# tensor(0.0973, dtype=torch.float64)
# tensor(0.0905, dtype=torch.float64)
# tensor(0.0841, dtype=torch.float64)
# tensor(0.0780, dtype=torch.float64)
# tensor(0.0722, dtype=torch.float64)
# tensor(0.0667, dtype=torch.float64)
# tensor(0.0614, dtype=torch.float64)
# tensor(0.0564, dtype=torch.float64)
# tensor(0.0516, dtype=torch.float64)
# tensor(0.0471, dtype=torch.float64)
# tensor(0.0429, dtype=torch.float64)
# tensor(0.0389, dtype=torch.float64)
# tensor(0.0351, dtype=torch.float64)
# tensor(0.0315, dtype=torch.float64)
# tensor(0.0282, dtype=torch.float64)
# tensor(0.0251, dtype=torch.float64)
# tensor(0.0222, dtype=torch.float64)

# %%
# check results
print(f"Weight: {w.item()}, Bias: {b.item()}")
y_pred = (torch.tensor(X_list)*w+b).detach().numpy()
sns.scatterplot(x=X_list, y=y_list)
sns.lineplot(x=X_list, y=y_pred, color='red')
# Out:
# Weight: -3.8575179884463795, Bias: 31.980193584941883
# <Axes: >

# %%
# %% (Statistical) Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_np, y_list)
print(f"Slope: {reg.coef_}, Bias: {reg.intercept_}")
# Out:
# Slope: [-5.3444715], Bias: 37.285125732421875

# %% [markdown]
# ### Visualise Neural Network

# %%
# !apt install libgraphviz-dev
# !pip install pygraphviz
# ! pip install torchviz

# %%
import os
from torchviz import make_dot
make_dot(loss_tensor)

# %% [markdown]
# ## Creating Model using Classes

# %%
#%% packages
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import seaborn as sns

# %%
#%% data import
cars_file = 'https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv'
cars = pd.read_csv(cars_file)
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# visualise the model
sns.scatterplot(x='wt', y='mpg', data=cars)
sns.regplot(x='wt', y='mpg', data=cars)
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
# convert data to tensors
X_list = cars.wt.values
X_np = np.array(X_list, dtype=np.float32).reshape(-1,1)
y_list = cars.mpg.values
y_np = np.array(y_list, dtype=np.float32).reshape(-1,1)
X = torch.from_numpy(X_np)
y_true = torch.from_numpy(y_np)

# %%
#building model

class LinearRegressionTorch(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearRegressionTorch, self).__init__()
        self.linear = nn.Linear(input_size, output_size)


    def forward(self, x):
        return self.linear(x)

input_dim = 1
output_dim = 1
model = LinearRegressionTorch(input_size=input_dim, output_size=output_dim)

# %%
# mean squared error
loss_fun = nn.MSELoss()

#learning rate
LR = 0.06

#optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=LR)

# %%
# training

losses, slope, bias = [], [], []
NUM_EPOCHS = 2000
for epoch in range(NUM_EPOCHS):

    # set gradients to zero
    optimizer.zero_grad()

    # forward pass
    y_pred = model(X)

    # calculate loss
    loss = loss_fun(y_pred, y_true)
    loss.backward()

    # update parameters
    optimizer.step()

    # get parameters
    for name, param in model.named_parameters():
        if param.requires_grad:
            if name == 'linear.weight':
                slope.append(param.data.numpy()[0][0])
            if name == 'linear.bias':
                bias.append(param.data.numpy()[0])
     # store loss
    losses.append(float(loss.data))
    # print loss
    if (epoch % 100 == 0):
        print(f"Epoch {epoch}, Loss: {loss.data}")
# Out:
# Epoch 0, Loss: 481.30877685546875
# Epoch 100, Loss: 25.39765739440918
# Epoch 200, Loss: 11.369626998901367
# Epoch 300, Loss: 9.125100135803223
# Epoch 400, Loss: 8.76596736907959
# Epoch 500, Loss: 8.708507537841797
# Epoch 600, Loss: 8.69931411743164
# Epoch 700, Loss: 8.69784164428711
# Epoch 800, Loss: 8.697606086730957
# Epoch 900, Loss: 8.697569847106934
# Epoch 1000, Loss: 8.697562217712402
# Epoch 1100, Loss: 8.697561264038086
# Epoch 1200, Loss: 8.697561264038086
# Epoch 1300, Loss: 8.69756031036377
# Epoch 1400, Loss: 8.697561264038086
# Epoch 1500, Loss: 8.697561264038086
# Epoch 1600, Loss: 8.697561264038086
# Epoch 1700, Loss: 8.697561264038086
# Epoch 1800, Loss: 8.697561264038086
# Epoch 1900, Loss: 8.697561264038086

# %%
# %% visualise model training
sns.scatterplot(x=range(NUM_EPOCHS), y=losses)

#%% visualise the bias development
sns.lineplot(x=range(NUM_EPOCHS), y=bias)
#%% visualise the slope development
sns.lineplot(x=range(NUM_EPOCHS), y=slope)
# Out:
# <Axes: >

# %%
# %% check the result
y_pred = model(X).data.numpy().reshape(-1)
sns.scatterplot(x=X_list, y=y_list)
sns.lineplot(x=X_list, y=y_pred, color='red')
# %%
# Out:
# <Axes: >

# %%
make_dot(loss)
